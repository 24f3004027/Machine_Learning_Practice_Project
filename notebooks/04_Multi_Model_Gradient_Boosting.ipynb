# %% [markdown]
# # 🄯 Copyleft 2026 Ramrup Satpati | All Rights Reversed
# ## Milestone 4: Multi-Model Tuning (XGBoost, LightGBM, CatBoost)
# **IIT Madras Machine Learning Practice (MLP) Project (S-Grade / 10.0 GPA)**
#
# In this milestone, we construct and tune 3 distinct gradient boosting architectures: Deep XGBoost (depth=9), LightGBM (127 leaves), and CatBoost regressors across 5-fold cross-validation.

# %%
from src.models import get_xgb_params, get_lgb_params, get_catboost_params

xgb_p = get_xgb_params(seed=42)
lgb_p = get_lgb_params(seed=42)
cat_p = get_catboost_params(seed=42)

print("Milestone 4: Multi-Model Gradient Boosting Hyperparameters Configured.")
print(f"XGBoost Max Depth: {xgb_p['max_depth']}, Learning Rate: {xgb_p['learning_rate']}")
print(f"LightGBM Num Leaves: {lgb_p['num_leaves']}, Learning Rate: {lgb_p['learning_rate']}")
print(f"CatBoost Depth: {cat_p['depth']}, Learning Rate: {cat_p['learning_rate']}")
